# %%
# Loading data from raw directory
import pandas as pd

df = pd.read_csv(r"../../data/raw/accidents_2005_to_2007_1.csv")
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  04/01/2005  ...
# ...

# %%
dfTwo = pd.read_csv(r"../../data/raw/accidents_2005_to_2007_1_2.csv")
dfTwo.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0       2.01E+12               465780.0                103730.0  -1.067368
# 1       2.01E+12               433750.0                 87060.0  -1.523666
# 2       2.01E+12               436650.0                145380.0  -1.476765
# 3       2.01E+12               459340.0                 92110.0  -1.160672
# 4       2.01E+12               467420.0                110350.0  -1.042867
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  50.829312            44                  3                   1
# 1  50.682156            44                  3                   2
# 2  51.206402            44                  3                   1
# 3  50.725522            44                  3                   1
# 4  50.888646            44                  3                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  01/12/2005  ...
# ...

# %%
dfThree = pd.read_csv(r"../../data/raw/accidents_2005_to_2007_2.csv")
dfThree.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200622DE50645               396430.0                273770.0  -2.053862
# 1  200622DE50650               407940.0                277040.0  -1.884759
# 2  200622DE50677               397420.0                268350.0  -2.039280
# 3  200622DE50798               396510.0                274480.0  -2.052694
# 4  200622DE50803               405340.0                266620.0  -1.923129
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  52.361941            22                  3                   2
# 1  52.391296            22                  3                   2
# 2  52.313219            22                  3                   2
# 3  52.368325            22                  3                   2
# 4  52.297647            22                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  26/03/2006  ...
# ...

# %%
dfFour = pd.read_csv(r"../../data/raw/accidents_2005_to_2007_2_1.csv")

dfFour.head()
# Out:
# /Users/dzhuravel/opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200706L073121               357970.0                405330.0  -2.635740
# 1  200706L073142               365730.0                399890.0  -2.518045
# 2  200706L073153               366890.0                398330.0  -2.500395
# 3  200706L073155               360450.0                397850.0  -2.597371
# 4  200706L073184               364500.0                400310.0  -2.536632
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  53.542912             6                  3                   2
# 1  53.494582             6                  3                   2
# ...

# %%
dfFive = pd.read_csv(r"../../data/raw/accidents_2009_to_2011_1.csv")
dfFive.head()
# Out:
# /Users/dzhuravel/opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200901BS70001                 524910                  180800  -0.201349
# 1  200901BS70002                 525050                  181040  -0.199248
# 2  200901BS70003                 526490                  177990  -0.179599
# 3  200901BS70004                 524800                  180300  -0.203110
# 4  200901BS70005                 526930                  177490  -0.173445
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.512273             1                  2                   2
# 1  51.514399             1                  2                   2
# ...

# %%
dfSix = pd.read_csv(r"../../data/raw/accidents_2009_to_2011_1_2.csv")

dfSix.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0    2.00944E+12                 445130                  111180  -1.359639
# 1    2.00944E+12                 462070                  153320  -1.111549
# 2    2.00944E+12                 458240                  103270  -1.174490
# 3    2.00944E+12                 465150                  100250  -1.076929
# 4    2.00944E+12                 436600                  106160  -1.481432
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  50.898278            44                  3                   1
# 1  51.275598            44                  3                   2
# 2  50.825982            44                  3                   2
# 3  50.798092            44                  2                   2
# 4  50.853739            44                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  30/08/2009  ...
# ...

# %%
dfSeven = pd.read_csv(r"../../data/raw/accidents_2009_to_2011_2.csv")

dfSeven.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0    2.01021E+12                 388520                  332430  -2.172077
# 1    2.01021E+12                 405330                  306820  -1.922644
# 2    2.01021E+12                 413020                  305800  -1.808992
# 3    2.01021E+12                 387400                  344040  -2.189177
# 4    2.01021E+12                 386560                  292410  -2.199559
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  52.889178            21                  3                   2
# 1  52.659051            21                  3                   1
# 2  52.649753            21                  3                   2
# 3  52.993519            21                  3                   1
# 4  52.529363            21                  3                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  01/01/2010  ...
# ...

# %%
dfEight = pd.read_csv(r"../../data/raw/accidents_2009_to_2011_2_1.csv")

dfEight.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0     2.0111E+12                 429660                  562390  -1.538379
# 1     2.0111E+12                 425180                  562450  -1.608328
# 2     2.0111E+12                 431950                  557550  -1.503157
# 3     2.0111E+12                 427640                  561670  -1.569989
# 4     2.0111E+12                 418470                  584630  -1.711677
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  54.955297            10                  3                   2
# 1  54.956081            10                  3                   1
# 2  54.911663            10                  3                   2
# 3  54.948942            10                  3                   1
# 4  55.155686            10                  3                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  13/08/2011  ...
# ...

# %%
dfNine = pd.read_csv(r"../../data/raw/accidents_2012_to_2014_1.csv")

dfNine.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
dfTen = pd.read_csv(r"../../data/raw/accidents_2012_to_2014_1_2.csv")

dfTen.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0       2.01E+12                 442828                  118826  -1.391475
# 1       2.01E+12                 479585                  135665  -0.864405
# 2       2.01E+12                 448944                  147299  -1.300531
# 3       2.01E+12                 444130                  119467  -1.372857
# 4       2.01E+12                 458119                   81697  -1.179603
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  50.967206            44                  3                   2
# 1  51.114699            44                  3                   2
# 2  51.222738            44                  3                   2
# 3  50.972871            44                  3                   2
# 4  50.632012            44                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  02/07/2012  ...
# ...

# %%
dfEleven = pd.read_csv(r"../../data/raw/accidents_2012_to_2014_2.csv")

dfEleven.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2013160C04471                 505420                  455609  -0.393740
# 1  2013160C04481                 495733                  427644  -0.550135
# 2  2013160C04491                 481679                  446047  -0.758259
# 3  2013160C04501                 519043                  428779  -0.196484
# 4  2013160C04511                 503718                  440042  -0.424959
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  53.985785            16                  3                   2
# 1  53.736399            16                  3                   2
# 2  53.904156            16                  3                   3
# 3  53.741801            16                  3                   2
# 4  53.846267            16                  3                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     2  05/08/2013  ...
# ...

# %%
dfTwelve = pd.read_csv(r"../../data/raw/accidents_2012_to_2014_2_1.csv")
dfTwelve.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201414K130314                 434490                  387147  -1.482979
# 1  201414K130614                 428005                  397932  -1.579510
# 2  201414K131214                 444718                  382587  -1.329874
# 3  201414K131914                 434218                  388068  -1.486968
# 4  201414K132614                 433573                  390048  -1.496456
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  53.380042            14                  3                   1
# 1  53.477365            14                  3                   3
# 2  53.338291            14                  3                   2
# 3  53.388338            14                  3                   7
# 4  53.406177            14                  3                   2
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  30/05/2014  ...
# ...

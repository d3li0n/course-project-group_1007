# %%
# Loading data from raw directory
import pandas as pd

df = pd.read_csv(r"../../data/raw/data.csv")
df.head()
# Out:
# /Users/dzhuravel/opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# ...
